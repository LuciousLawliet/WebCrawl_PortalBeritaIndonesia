# %% [markdown]
# #Test

# %%
# !pip install scrapy
# !pip install properties
# !pip install items
# !pip install requests_html
# !pip install mariadb

# %% [markdown]
# #Database

# %%
#!/usr/bin/python 
import mariadb 

conn = mariadb.connect(
    user="root",
    password=" ",
    host="localhost",
    database="webCrawl")
cur = conn.cursor() 

#retrieving information 
cur.execute("SELECT * ", (some_name,)) 

for first_name, last_name in cur: 
    print(f"First name: {first_name}, Last name: {last_name}")
    
#insert information 
try: 
    cur.execute("INSERT INTO employees (first_name,last_name) VALUES (?, ?)", ("Maria","DB")) 
except mariadb.Error as e: 
    print(f"Error: {e}")

conn.commit() 
print(f"Last Inserted ID: {cur.lastrowid}")
    
conn.close()

# %% [markdown]
# #Otomatis

# %%
from requests_html import HTMLSession
import numpy as np
import requests
from requests import get
from bs4 import BeautifulSoup
import time
import random

keyword = input('Masukkan nama web: ')
web_url = input('Masukkan URL web: ')

keyword = keyword.lower()
if keyword == 'cnbc' or 'cnbc indonesia' or 'cnbcindonesia':
  session = HTMLSession()
  pages = np.arange(1,2,1)
  newslist = []
  for page in pages:
    r = session.get("https://www.cnbcindonesia.com/search?query=rni&p=" + str(page) + "&kanal=&tipe=&date=")
    articles = r.html.find('article')
    for item in articles:
      try:
        newsitem = item.find('a', first=True)
        title = newsitem.text
        link = newsitem.absolute_links
        newsarticle = {
            'title': title,
            'link': link 
        }
        newslist.append(newsarticle)
      except:
        pass
  print(len(newslist))
  for i in newslist:
    print(i)
elif keyword == 'antaranews' or 'antara news':
  pages = np.arange(1,2,1)
  news_all = []
  for page in pages:
    time.sleep(random.randint(1,10))
    url = 'https://www.antaranews.com/search/rajawali+nusantara+indonesia/' + str(page)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')
    news = soup.find_all('article', class_='simple-post simple-big clearfix')
    for container in news:
      headline = container.header.h3.a.text
      link = container.header.h3.a['href']        
      newsarticle = {        
          'title': headline,
          'link': link
      }
      news_all.append(newsarticle)
      #summary = container.div.p.text
      #news_summary.append(summary)
  print(len(news_all))
  for i in news_all:
    print(i)
# Out:
# Masukkan nama web: antaraNews
# Masukkan URL web: antaranews
# 12
# {'title': 'Dua Kawasan Rebana Akan Ditawarkan ke Investor Timur Tengah\nNews - 1 hari yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20211011111649-4-282911/dua-kawasan-rebana-akan-ditawarkan-ke-investor-timur-tengah'}}
# {'title': 'Tekan Subsidi Pupuk, BRI-Pupuk Indonesia Bikin Program Makmur\nMarket - 1 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/market/20210930124642-17-280377/tekan-subsidi-pupuk-bri-pupuk-indonesia-bikin-program-makmur'}}
# {'title': 'Utak Atik BUMN Demi Holding Pangan, Apa Dampaknya?\nNews - 2 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210922191331-4-278391/utak-atik-bumn-demi-holding-pangan-apa-dampaknya'}}
# {'title': 'Mendag Klaim RI Bisa Ekspor Beras Harga Suka-suka, Kok Bisa?\nNews - 3 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210916162809-4-276885/mendag-klaim-ri-bisa-ekspor-beras-harga-suka-suka-kok-bisa'}}
# ...

# %%
print(keyword)
# Out:
# antaranews

# %% [markdown]
# #Manual

# %% [markdown]
# ##Testing

# %%
dam = 'aku'

if dam == 'aku':
  print('aku')
elif dam == 'saya':
  print('saya')
# Out:
# aku

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.goodreads.com/search?q=dilan'

r = requests.get(url)

request = r.content

soup = BeautifulSoup(request, 'html.parser')

title = soup.findAll('a', attrs={'class':'bookTitle'})
author = soup.findAll('a', attrs={'class':'authorName'})

count = 0
for x in range(0, len(title)):
	count += 1
	print("{0}. {1}\n      .{2}"
		.format(count, title[x].text.strip(), author[x].text.strip()))

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cnbcindonesia.com/search?query=rni'
#url = 'https://www.tribunnews.com/search?q=rni&cx=partner-pub-7486139053367666%3A4965051114&cof=FORID%3A10&ie=UTF-8&siteurl=www.tribunnews.com'

r = requests.get(url)

request = r.content

soup = BeautifulSoup(request, 'html.parser')

title = soup.findAll('h2')
author = soup.findAll('h2')

count = 0
for x in range(0, len(title)):
	count += 1
	print("{0}. {1}\n      .{2}"
		.format(count, title[x].text.strip(), author[x].text.strip()))

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.tribunnews.com/search?q=rni&cx=partner-pub-7486139053367666%3A4965051114&cof=FORID%3A10&ie=UTF-8&siteurl=www.tribunnews.com'

r = requests.get(url)

request = r.content

soup = BeautifulSoup(request, 'html.parser')

articles = soup.findAll("div", class_="gs-title")
#author = soup.findAll('h2')


for item in articles:
	try:
        newsitem = item.find('a', first=True)
        title = newsitem.text
        link = newsitem.absolute_links
        newsarticle = {
            'title': title,
            'link': link 
        }
        newslist.append(newsarticle)
    except:
       pass

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://search.kompas.com/search/?q=rni&submit=Submit'

r = requests.get(url)

request = r.content

soup = BeautifulSoup(request, 'html.parser')

title = soup.findAll('a', attrs={'data-cturl':'https://www.google.com/url?client=internal-element-cse&cx=018212539862037696382:-xa61bkyvao&q=https://money.kompas.com/read/2021/08/19/161959926/dirut-rni-holding-bumn-pangan-rampung-akhir-september-2021%3Fpage%3Dall&sa=U&ved=2ahUKEwjXn8CZm8HzAhXoxDgGHYOwDGUQFnoECAEQAg&usg=AOvVaw1vwk2lQZFK7p7Xbhjr7sKd'})
author = soup.findAll('a', attrs={'div':'ltr'})

count = 0
for x in range(0, len(title)):
	count += 1
	print("{0}. {1}\n      .{2}"
		.format(count, title[x].text.strip(), author[x].text.strip()))

# %% [markdown]
# ##CNBC

# %%
from requests_html import HTMLSession
import numpy as np

session = HTMLSession()
pages = np.arange(1,12,1)

newslist = []

for page in pages:
  r = session.get("https://www.cnbcindonesia.com/search?query=rni&p=" + str(page) + "&kanal=&tipe=&date=")
  articles = r.html.find('article')

  for item in articles:
    try:
        newsitem = item.find('a', first=True)
        title = newsitem.text
        link = newsitem.absolute_links
        newsarticle = {
            'title': title,
            'link': link 
        }
        newslist.append(newsarticle)
    except:
       pass 

print(len(newslist))
for i in newslist:
  print(i)
# Out:
# 121
# {'title': 'Dua Kawasan Rebana Akan Ditawarkan ke Investor Timur Tengah\nNews - 23 jam yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20211011111649-4-282911/dua-kawasan-rebana-akan-ditawarkan-ke-investor-timur-tengah'}}
# {'title': 'Tekan Subsidi Pupuk, BRI-Pupuk Indonesia Bikin Program Makmur\nMarket - 1 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/market/20210930124642-17-280377/tekan-subsidi-pupuk-bri-pupuk-indonesia-bikin-program-makmur'}}
# {'title': 'Utak Atik BUMN Demi Holding Pangan, Apa Dampaknya?\nNews - 2 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210922191331-4-278391/utak-atik-bumn-demi-holding-pangan-apa-dampaknya'}}
# {'title': 'Mendag Klaim RI Bisa Ekspor Beras Harga Suka-suka, Kok Bisa?\nNews - 3 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210916162809-4-276885/mendag-klaim-ri-bisa-ekspor-beras-harga-suka-suka-kok-bisa'}}
# ...

# %% [markdown]
# ##CNN

# %%
from requests_html import HTMLSession
import numpy as np

session = HTMLSession()
pages = np.arange(1,12,1)

newslist = []

for page in pages:
  r = session.get("https://www.cnbcindonesia.com/search?query=rni&p=" + str(page) + "&kanal=&tipe=&date=")
  articles = r.html.find('article')

  for item in articles:
    try:
        newsitem = item.find('a', first=True)
        title = newsitem.text
        link = newsitem.absolute_links
        newsarticle = {
            'title': title,
            'link': link 
        }
        newslist.append(newsarticle)
    except:
       pass 

print(len(newslist))
for i in newslist:
  print(i)
# Out:
# 121
# {'title': 'Dua Kawasan Rebana Akan Ditawarkan ke Investor Timur Tengah\nNews - 23 jam yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20211011111649-4-282911/dua-kawasan-rebana-akan-ditawarkan-ke-investor-timur-tengah'}}
# {'title': 'Tekan Subsidi Pupuk, BRI-Pupuk Indonesia Bikin Program Makmur\nMarket - 1 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/market/20210930124642-17-280377/tekan-subsidi-pupuk-bri-pupuk-indonesia-bikin-program-makmur'}}
# {'title': 'Utak Atik BUMN Demi Holding Pangan, Apa Dampaknya?\nNews - 2 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210922191331-4-278391/utak-atik-bumn-demi-holding-pangan-apa-dampaknya'}}
# {'title': 'Mendag Klaim RI Bisa Ekspor Beras Harga Suka-suka, Kok Bisa?\nNews - 3 minggu yang lalu', 'link': {'https://www.cnbcindonesia.com/news/20210916162809-4-276885/mendag-klaim-ri-bisa-ekspor-beras-harga-suka-suka-kok-bisa'}}
# ...

# %% [markdown]
# ##InvestorID

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import time
import random

pages = np.arange(1,6,1)

news_all = []

for page in pages:
    time.sleep(random.randint(1,10))
    
    url = 'https://investor.id/search/?keyword=rni&page=' + str(page)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')

    news = soup.find_all('div', class_='listview-content pb10 mb20')

    for container in news:
        headline = container.div.p.a.text
        link = container.div.p.a['href']        

        newsarticle = {
            'title': headline,
            'link': link
        }
        news_all.append(newsarticle)

        #summary = container.div.p.text
        #news_summary.append(summary)

print(len(news_all))
for i in news_all:
  print(i)
# Out:
# 90
# {'title': '\n\t\t\t\t\t\t\t\t\tIni Rencana Besar di Balik Merger PT Pertani dengan SHS', 'link': 'https://investor.id/business/266275/ini-rencana-besar-di-balik-merger-pt-pertani-dengan-shs'}
# {'title': '\n\t\t\t\t\t\t\t\t\tAnak Usaha RNI Jaga Kemitraan dengan Petani Tebu', 'link': 'https://investor.id/business/266032/anak-usaha-rni-jaga-kemitraan-dengan-petani-tebu'}
# {'title': '\n\t\t\t\t\t\t\t\t\tErick: Kinerja Badan Pangan Nasional Paling Ditunggu', 'link': 'https://investor.id/business/263675/erick-kinerja-badan-pangan-nasional-paling-ditunggu'}
# {'title': '\n\t\t\t\t\t\t\t\t\tErick Ingin Kolaborasi BUMN dan Swasta Saling Untung', 'link': 'https://investor.id/business/263619/erick-ingin-kolaborasi-bumn-dan-swasta-saling-untung'}
# {'title': '\n\t\t\t\t\t\t\t\t\tPemerintah Dorong Koperasi dan UMKM Masuk Rantai Pasok Global', 'link': 'https://investor.id/business/262193/pemerintah-dorong-koperasi-dan-umkm-masuk-rantai-pasok-global'}
# ...

# %% [markdown]
# ##AntaraNews

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import time
import random

pages = np.arange(1,2,1)

news_all = []

for page in pages:
    time.sleep(random.randint(1,10))
    
    url = 'https://www.antaranews.com/search/rajawali+nusantara+indonesia/' + str(page)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')

    news = soup.find_all('article', class_='simple-post simple-big clearfix')

    for container in news:
        headline = container.header.h3.a.text
        link = container.header.h3.a['href']        

        newsarticle = {
            'title': headline,
            'link': link
        }
        news_all.append(newsarticle)

        #summary = container.div.p.text
        #news_summary.append(summary)

print(len(news_all))
for i in news_all:
  print(i)
# Out:
# 10
# {'title': 'Apresiasi kepada BUMN kembali digelar dalam Indonesia BUMN Awards 2021', 'link': 'https://www.antaranews.com/berita/2456657/apresiasi-kepada-bumn-kembali-digelar-dalam-indonesia-bumn-awards-2021'}
# {'title': 'PT RNI ungkap harmonisasi inbreng Holding BUMN Pangan sudah dilakukan', 'link': 'https://www.antaranews.com/berita/2453517/pt-rni-ungkap-harmonisasi-inbreng-holding-bumn-pangan-sudah-dilakukan'}
# {'title': 'RNI: Digitalisasi sektor pangan penting turunkan biaya produksi', 'link': 'https://www.antaranews.com/berita/2453297/rni-digitalisasi-sektor-pangan-penting-turunkan-biaya-produksi'}
# {'title': 'PT RNI ajak milenial jadi petani tebu bantu transformasi industri gula', 'link': 'https://www.antaranews.com/berita/2443065/pt-rni-ajak-milenial-jadi-petani-tebu-bantu-transformasi-industri-gula'}
# ...

# %% [markdown]
# ##Bisnis.com

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import time
import random

pages = np.arange(1,28,1)

news_all = []

for page in pages:
    time.sleep(random.randint(1,10))
    
    url = 'https://search.bisnis.com/?q=rni&per_page=' + str(page)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')

    news = soup.find_all('div', class_='col-sm-8')

    for container in news:
        headline = container.h2.a.text
        link = container.h2.a['href']        

        newsarticle = {
            'title': headline,
            'link': link
        }
        news_all.append(newsarticle)

        #summary = container.div.p.text
        #news_summary.append(summary)

print(len(news_all))
for i in news_all:
  print(i)
# Out:
# 266
# {'title': 'Instruksi Erick Thohir Ciptakan Industri Telur Olahan Dalam Negeri', 'link': 'https://ekonomi.bisnis.com/read/20211010/12/1452630/instruksi-erick-thohir-ciptakan-industri-telur-olahan-dalam-negeri'}
# {'title': 'Dirut RNI Dukung Merger BUMN Klaster Pangan BGR ke PPI', 'link': 'https://ekonomi.bisnis.com/read/20210924/12/1446678/dirut-rni-dukung-merger-bumn-klaster-pangan-bgr-ke-ppi'}
# {'title': 'Kementerian BUMN Akan Bubarkan 7 BUMN, Ada Merpati Air dan Iglas', 'link': 'https://market.bisnis.com/read/20210924/192/1446385/kementerian-bumn-akan-bubarkan-7-bumn-ada-merpati-air-dan-iglas'}
# {'title': 'Dirut RNI Ungkap Kekuatan Holding BUMN Pangan Pasca Merger', 'link': 'https://ekonomi.bisnis.com/read/20210921/99/1445238/dirut-rni-ungkap-kekuatan-holding-bumn-pangan-pasca-merger'}
# {'title': 'Jokowi Restui Merger Holding BUMN Klaster Pangan', 'link': 'https://ekonomi.bisnis.com/read/20210916/12/1443085/jokowi-restui-merger-holding-bumn-klaster-pangan'}
# ...

# %% [markdown]
# #TESTING

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import time
import random

pages = np.arange(1,2,1)

book_title = []
star_rating = []
product_price = []

for page in pages:
    time.sleep(random.randint(1,10))
    
    url = 'http://books.toscrape.com/catalogue/page-' + str(page) + '.html'
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')

    book_div = soup.find_all('li', class_='col-xs-6 col-sm-4 col-md-3 col-lg-3')

    for container in book_div:
        title = container.article.h3.a['title']
        book_title.append(title)

        price = container.article.find('div', class_='product_price').p.text
        product_price.append(price)

        rating = container.article.p['class'][-1]
        star_rating.append(rating)
    
for i in book_div:
      print(i)

# %%
import pandas as pd
#col_dict = {'title':book_title, 'price':product_price, 'rating':star_rating}
col_dict = {text:book_title}
book_store = pd.DataFrame(col_dict)

print(book_store.head())
print(book_store.dtypes)

book_store['price'] = book_store['price'].apply(lambda x : float(x[2:]))

number_mapping = {'One':1,'Two':2,'Three':3,'Four':4,'Five':5}
book_store['rating'] = book_store['rating'].apply(lambda x : number_mapping.get(x))

print(book_store.head())
print(book_store.dtypes)

# %% [markdown]
# ##Google

# %%
https://www.google.com/search?q=rni&tbm=nws&ei=GjFmYb7RO4e7rQG53piICA&start=10&sa=N&ved=2ahUKEwi-xqeWmcbzAhWHXSsKHTkvBoEQ8tMDegQIARA3&biw=1114&bih=875&dpr=1.1

import requests
from requests import get
from bs4 import BeautifulSoup
import numpy as np
import time
import random

pages = np.arange(1,28,1)

news_all = []

for page in pages:
    time.sleep(random.randint(1,10))
    
    url = 'https://www.google.co.id/search?q=rni&tbm=nws' + str(page)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')

    news = soup.find_all('div', class_='col-sm-8')

    for container in news:
        headline = container.h2.a.text
        link = container.h2.a['href']        

        newsarticle = {
            'title': headline,
            'link': link
        }
        news_all.append(newsarticle)

        #summary = container.div.p.text
        #news_summary.append(summary)

print(len(news_all))
for i in news_all:
  print(i)

# %%
import requests, lxml
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}

params = {
    "q": "gta san andreas",
    "hl": "en",
    "tbm": "nws",
}

response = requests.get("https://www.google.com/search", headers=headers, params=params)
soup = BeautifulSoup(response.text, 'lxml')

for result in soup.select('.dbsr'):
    title = result.select_one('.nDgy9d').text
    link = result.a['href']
    source = result.select_one('.WF4CUc').text
    snippet = result.select_one('.Y3v8qd').text
    date_published = result.select_one('.WG9SHc span').text
    print(f'{title}\n{link}\n{snippet}\n{date_published}\n{source}\n')

# %% [markdown]
# #Portal yang Tidak/Belum Bisa

# %%
#beritasatu belum bisa
"""
elif web_name == 'beritasatu' or web_name == 'beritasatu.com':
  for page in pages:
    time.sleep(random.randint(1,10))
    pages = np.arange(1,30,1)
    url = 'https://www.beritasatu.com/search/' + str(keyword)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')
    news = soup.find('div', class_='row')
    for container in news:
        headline = container.a.text
        link = container.a['href']     
        newsarticle = {
            'title': headline,
            'link': link
        }
        newslist.append(newsarticle)
  print(len(newslist))
  for i in newslist:
    print(i)
"""

"""
elif web_name == 'liputan6' or web_name == 'liputan6.com':
  for page in pages:
    time.sleep(random.randint(1,10))
    pages = np.arange(1,5,1)
    #url = 'https://www.liputan6.com/search?q=' + str(keyword) + '&type=all'
    url = 'https://www.liputan6.com/search?q=rni'
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')
    news = soup.find_all('h4', class_='articles--iridescent-list--text-item__title')
    for container in news:
        headline = container.a['title']
        link = container.a['href']     
        newsarticle = {
            'title': headline,
            'link': link
        }
        newslist.append(newsarticle)
  print(len(newslist))
  for i in newslist:
    print(i)
"""
#agrofarm tidak bisa
elif web_name == 'agrofarm' or web_name == 'agro farm' or web_name == 'agro':
  for page in pages:
    time.sleep(random.randint(1,10))
    url = 'https://www.agrofarm.co.id/page/' + str(page) + '/?s=' + str(keyword)
    results = requests.get(url)
    soup = BeautifulSoup(results.text, 'html.parser')
    news = soup.find_all('h2', class_='post-box-title')
    for container in news:
        headline = container.a.text
        link = container.a['href']        
        newsarticle = {
            'title': headline,
            'link': link
        }
        newslist.append(newsarticle)
  print(len(newslist))
  for i in newslist:
    print(i)
#CNN belum bisa
#okezone tidak bisa
#viva tidak bisa
#trinbunnews tidak bisa
#jawapos artikel sedikit (kurang dari 10)
#liputan6 tidak bisa
